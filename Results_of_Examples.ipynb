# %% [markdown]
# File containing results of all examples used throughout the thesis.
#
# We run the file containing functions for homotopy continuation and certification, which also contains the data for our examples:

# %%
# %run Homotopy_Continuation_and_Certification.ipynb

# %% [markdown]
# Example 1:
# 1a, 1b, 1c: Plots of $h(x,t)=((1-t)\gamma-t) x^4+t(4+\gamma)-\gamma$ for 100 iterations of constant stepsize $\Delta t=\frac{1}{100}$ using Algorithm 3.3.1. Plot for $\gamma$=(random number) (1a), $\gamma=-1$ (1b), and $\gamma=i$ (1c).

# %%
print(Homotopy_Continuation_1(E.Polynomial_System_1a))
print(Homotopy_Continuation_1(*E.Polynomial_System_1b))
print(Homotopy_Continuation_1(*E.Polynomial_System_1c))
# Out:
# ['Solution 1: [[1.41421356-6.86509189e-11j]]', 'Solution 2: [[6.86509189e-11+1.41421356j]]', 'Solution 3: [[-1.41421356+6.86509189e-11j]]', 'Solution 4: [[-6.86509189e-11-1.41421356j]]']
# ['Solution 1: [[1.41421356+0.j]]', 'Solution 2: [[0.+1.41421356j]]', 'Solution 3: [[-1.41421356+0.j]]', 'Solution 4: [[0.-1.41421356j]]']
# ['Solution 1: [[1.41421356-1.12528624e-09j]]', 'Solution 2: [[1.12528624e-09+1.41421356j]]', 'Solution 3: [[-1.41421356+1.12528624e-09j]]', 'Solution 4: [[-1.12528624e-09-1.41421356j]]']

# %% [markdown]
# Example 2: Solutions and intermediate solutions for the positive and real path of the straight-line homotopy for $f(x)=x^4-1$, where the maximum number of iterations at the corrector method to 0, 1 and 3 respectively, and the threshold for convergence in Newton's method is $10^{-12}$. The function corresponds to Algorithm 3.3.1.

# %%
print(Homotopy_Continuation_2_table(*E.Polynomial_System_2a)[0])
print(Homotopy_Continuation_2_table(*E.Polynomial_System_2b)[0])
print(Homotopy_Continuation_2_table(*E.Polynomial_System_2c)[0])
# Out:
# Solution 1: [[1.42892312+0.j]], Intermediate solutions at each iteration: [array([[1.+0.j]]), array([[1.075+0.j]]), array([[1.13537204+0.j]]), array([[1.18661647+0.j]]), array([[1.23150446+0.j]]), array([[1.27166073+0.j]]), array([[1.30813171+0.j]]), array([[1.3416365+0.j]]), array([[1.37269329+0.j]]), array([[1.40168947+0.j]]), array([[1.42892312+0.j]])]
# Solution 1: [[1.41421427+0.j]], Intermediate solutions at each iteration: [array([[1.+0.j]]), array([[1.06786219+0.j]]), array([[1.12471279+0.j]]), array([[1.17406935+0.j]]), array([[1.21789113+0.j]]), array([[1.25743807+0.j]]), array([[1.29357166+0.j]]), array([[1.32690876+0.j]]), array([[1.35790742+0.j]]), array([[1.38691783+0.j]]), array([[1.41421427+0.j]])]
# ...

# %% [markdown]
# Example 3: Solution for the positive real path of the homotopy for $f(x)=x^4-1$ with adaptive stepsize and changing criteria for newton step, corresponding to Algorithm 4.1.1, with initial stepsize 0.1.

# %%
print(Homotopy_Continuation_3(*E.Polynomial_System_3)[0])
# Out:
# Solution 1: [[1.41421356+0.j]], Number of steps: 8, Number of newton iterations: 3

# %% [markdown]
# Example 4: Solution to the homotopy of the functions $F_{4a}(x,y)=(x^2-1000x,y-1)$ and $F_{4b}(x,y)=(y^2+x+1,x+xy+3)$, using Algorithm 4.4.1 (Homotopy_Continuation_4) with Runge-Kutta instead of Euler's Method and using Algorithm 4.2.1 (Homotopy_Continuation_5)

# %%
print(Homotopy_Continuation_4(*E.Polynomial_System_4a)[0])
print(Homotopy_Continuation_4(*E.Polynomial_System_4b)[0])
print(Homotopy_Continuation_5(*E.Polynomial_System_4a)[0])
print(Homotopy_Continuation_5(*E.Polynomial_System_4b)[0])
# Out:
# ['Solution 1: [[1000.+0.j]\n [   1.+0.j]], Number of steps: 60, Number of newton iterations: 7', 'Solution 2: [[-2.76132741e-19-1.46281043e-53j]\n [ 1.00000000e+00+0.00000000e+00j]], Number of steps: 60, Number of newton iterations: 6']
# ['Solution 1: [[-2.+0.j]\n [-1.+0.j]], Number of steps: 113, Number of newton iterations: 77', 'Solution 2: Path is going to infinity, Number of steps: 53, Number of newton iterations: 30']
# ['Solution 1: [[1000.+0.j]\n [   1.+0.j]], Number of Euler steps: 0, Number of ABAM steps: 97, Number of newton iterations: 30', 'Solution 2: [[3.61776361e-13+1.10323753e-85j]\n [1.00000000e+00+0.00000000e+00j]], Number of Euler steps: 0, Number of ABAM steps: 97, Number of newton iterations: 30']
# ...

# %% [markdown]
# Example 5: Solution to the homotopy of the function $F(x,y)=(x^2+y^2-1,(x-1)^2+(y-1)^2-1) using maximal change of $10^{18}$ and $10^{19}$ respectively:

# %%
print(Homotopy_Continuation_6(*E.Polynomial_System_5a))
print(Homotopy_Continuation_6(*E.Polynomial_System_5b))
# Out:
# ['Solution 1: Path is going to infinity', 'Solution 2: [[1.00000000e+00+1.90594045e-21j]\n [3.88647537e-17-1.90593399e-21j]]', 'Solution 3: [[-1.67449507e-18+1.06677542e-20j]\n [ 1.00000000e+00-1.06677606e-20j]]', 'Solution 4: Path is going to infinity']
# ['Solution 1: [[0.06050862+0.14613889j]\n [0.93949138-0.14613889j]]', 'Solution 2: [[1.00000000e+00+1.90594045e-21j]\n [3.88647537e-17-1.90593399e-21j]]', 'Solution 3: [[-1.67449507e-18+1.06677542e-20j]\n [ 1.00000000e+00-1.06677606e-20j]]', 'Solution 4: [[0.05427808+0.1462491j]\n [0.94572192-0.1462491j]]']

# %% [markdown]
# Example 6: Solution to the homotopy of the systems $F_{6a}(x,y)=(x-2)$ and $F_{6b}(x,y)=(x^2-1000x)$ using Algorithm 4.1.1 with Runge-Kutta with 10000 iterations and $\gamma=0.8+0.6i$.

# %%
print(Homotopy_Continuation_7(*E.Polynomial_System_6a))
print(Homotopy_Continuation_7(*E.Polynomial_System_6b))
# Out:
# ['Solution 1: [[2.+4.36632176e-14j]]', 'Solution 2: Path is going to infinity']
# ['Solution 1: Path is going to infinity', 'Solution 2: [[9.23014062e-18+6.90550268e-18j]]']

# %% [markdown]
# Example 6: Solution to the homotopy of the systems $F_{6a}(x,y)=(x-2)$ and $F_{6b}(x,y)=(x^2-1000x)$ using Algorithm 4.1.1 with Runge-Kutta and a projective transformation $(a,b)=0.8+0.6i,0.2+0.4i$

# %%
print(Homotopy_Continuation_8_proj(*E.Polynomial_System_6a_proj))
print(Homotopy_Continuation_8_proj(*E.Polynomial_System_6b_proj))
# Out:
# (['Affine Solution 1: [2.+1.13464793e-14j]', 'Affine Solution 2: Path is going to infinity'], ['Projective Solution 1: [[0.35294118-0.41176471j]\n [0.70588235-0.82352941j]]', 'Projective Solution 2: Path is going to point at infinity [[-3.73482481e-13+8.41743938e-14j]\n [ 1.00000000e+00-2.00000000e+00j]]'])
# (['Affine Solution 1: [1000.-5.33706412e-13j]', 'Affine Solution 2: [1.13768911e-17+7.08251893e-20j]'], ['Projective Solution 1: [[9.9999502e-04-1.99500999e-03j]\n [9.9999502e-01-1.99500999e+00j]]', 'Projective Solution 2: [[8.00000000e-01-6.00000000e-01j]\n [9.14400796e-18-6.76947448e-18j]]'])

# %% [markdown]
# Example 7: Solutions to $F(x)=x1**2-1,x2**2-2*x1,x3**2-x2*x1$ by homotopy continuation using Algorithm 5.2.1 with Algorithm 4.1.1 with Runge-Kutta, and with Algorithm 4.2.1, respecitvely.

# %%
Homotopy_Continuation_A(E.Polynomial_System_7)[1:]
# Out:
# (['Affine Solution 1: [[1.        +0.00000000e+00j]\n [1.41421356+0.00000000e+00j]\n [1.18920712+1.55027754e-17j]]',
#   'Affine Solution 2: [[ 1.        -0.00000000e+00j]\n [ 1.41421356-8.44839424e-16j]\n [-1.18920712+4.43540698e-15j]]',
#   'Affine Solution 3: [[ 1.00000000e+00+0.00000000e+00j]\n [-1.41421356e+00-8.88458397e-16j]\n [-4.44229198e-16-1.18920712e+00j]]',
#   'Affine Solution 4: [[ 1.00000000e+00+0.j        ]\n [-1.41421356e+00+0.j        ]\n [ 9.16940863e-16+1.18920712j]]',
#   'Affine Solution 5: [[-1.00000000e+00+0.j        ]\n [-4.60795532e-14+1.41421356j]\n [ 8.40896415e-01-0.84089642j]]',
#   'Affine Solution 6: [[-1.00000000e+00+9.37437286e-17j]\n [-1.68738712e-15+1.41421356e+00j]\n [-8.40896415e-01+8.40896415e-01j]]',
#   'Affine Solution 7: [[-1.00000000e+00-0.j        ]\n [-1.94714406e-13-1.41421356j]\n [ 8.40896415e-01+0.84089642j]]',
#   'Affine Solution 8: [[-1.00000000e+00+0.j        ]\n [ 3.06415365e-14-1.41421356j]\n [-8.40896415e-01-0.84089642j]]'],
# ...

# %%
Homotopy_Continuation_B(E.Polynomial_System_7)[1:]
# Out:
# (['Affine Solution 1: [[1.        +0.00000000e+00j]\n [1.41421356-2.47102420e-14j]\n [1.18920712+1.82743044e-14j]]',
#   'Affine Solution 2: [[ 1.        +0.00000000e+00j]\n [ 1.41421356-1.84547628e-15j]\n [-1.18920712-8.20211680e-16j]]',
#   'Affine Solution 3: [[ 1.00000000e+00-0.00000000e+00j]\n [-1.41421356e+00+1.71146270e-13j]\n [ 3.60444416e-13+1.18920712e+00j]]',
#   'Affine Solution 4: [[ 1.00000000e+00+0.00000000e+00j]\n [-1.41421356e+00-3.80930491e-14j]\n [-3.81678881e-14-1.18920712e+00j]]',
#   'Affine Solution 5: [[-1.00000000e+00+0.j        ]\n [ 2.69018830e-13+1.41421356j]\n [ 8.40896415e-01-0.84089642j]]',
#   'Affine Solution 6: [[-1.00000000e+00+0.j        ]\n [-6.28958477e-14-1.41421356j]\n [-8.40896415e-01-0.84089642j]]',
#   'Affine Solution 7: [[-1.00000000e+00+0.j        ]\n [ 6.72987765e-14-1.41421356j]\n [ 8.40896415e-01+0.84089642j]]',
#   'Affine Solution 8: [[-1.        +0.j        ]\n [ 0.        +1.41421356j]\n [-0.84089642+0.84089642j]]'],
# ...

# %% [markdown]
# Example 8: Solutions and certification of 2 link planar robot using Algorithm 4.2.1:

# %%
Inverse_Kinematic_Solutions_planar_robot, sol_data_planar_robot=Homotopy_Continuation_5(*E.Polynomial_System_2R)
print(Inverse_Kinematic_Solutions_planar_robot)
print(certify(E.F_planar_robot,sol_data_planar_robot))
# Out:
# ['Solution 1: Path is going to infinity, Number of Euler steps: 617, Number of ABAM steps: 361, Number of newton iterations: 695', 'Solution 2: Path is going to infinity, Number of Euler steps: 643, Number of ABAM steps: 335, Number of newton iterations: 720', 'Solution 3: Path is going to infinity, Number of Euler steps: 253, Number of ABAM steps: 724, Number of newton iterations: 332', 'Solution 4: Path is going to infinity, Number of Euler steps: 502, Number of ABAM steps: 475, Number of newton iterations: 581', 'Solution 5: [[ 0.9479445 +2.16439426e-12j]\n [-0.67178447-4.53902448e-12j]\n [ 0.31843558+8.72519477e-13j]\n [ 0.74074667-4.82111261e-12j]], Number of Euler steps: 729, Number of ABAM steps: 268, Number of newton iterations: 729', 'Solution 6: [[ 0.22724258+5.97508696e-13j]\n [-0.67178447-6.69916152e-12j]\n [ 0.97383818+1.12496479e-13j]\n [-0.74074667+3.72432987e-13j]], Number of Euler steps: 687, Number of ABAM steps: 310, Number of newton iterations: 688', 'Solution 7: 
# ...

# %% [markdown]
# Example 8: Coefficient-Parameter Homotopies. Solving 2 link planar robot for new parameters using previous solutions as start system.

# %%
sol_data_planar_robot_new=Homotopy_Continuation_CP(E.F_planar_robot,sol_data_planar_robot,E.F_planar_robot_new,E.U_comp_planar_robot,1000,(-1+1j)/(2**(1/2)))
print(certify(E.F_planar_robot_new,sol_data_planar_robot_new))
# Out:
# ('Certified solutions: 2 (total: 2), Exactly 2 real solutions, Exactly 2 distinct solutions, Maximal real and imaginary inaccuracy: 0.010726746712454181', [(array([[ 0.875     +4.66388520e-15j],
#        [-0.25      +1.26340733e-14j],
#        [-0.48412292+4.95365990e-15j],
#        [ 0.96824584-1.91744252e-14j]]), 'Real: True', 'Distinct'), (array([[ 0.875     -4.45014404e-16j],
#        [-0.25      -1.66156455e-16j],
#        [ 0.48412292+1.47787384e-15j],
#        [-0.96824584-3.17424326e-15j]]), 'Real: True', 'Distinct')])

# %% [markdown]
# Example 9: 6R-serial link robot. Find solutions by homotopy continuation of total degree start system using Algorithm 4.2.1.

# %%
Inverse_Kinematic_Solutions_6R, sol_data_6R=Homotopy_Continuation_5(E.F_6R_serial,1000,(-1+1j)/(2**(1/2)))
print(Inverse_Kinematic_Solutions_6R)
# Out:
# ['Solution 1: Path is going to infinity, Number of Euler steps: 0, Number of ABAM steps: 341, Number of newton iterations: 38', 'Solution 2: Path is going to infinity, Number of Euler steps: 0, Number of ABAM steps: 927, Number of newton iterations: 178', 'Solution 3: Path is going to infinity, Number of Euler steps: 0, Number of ABAM steps: 328, Number of newton iterations: 4', 'Solution 4: Path is going to infinity, Number of Euler steps: 0, Number of ABAM steps: 953, Number of newton iterations: 57', 'Solution 5: Path is going to infinity, Number of Euler steps: 0, Number of ABAM steps: 384, Number of newton iterations: 78', 'Solution 6: Path is going to infinity, Number of Euler steps: 0, Number of ABAM steps: 351, Number of newton iterations: 32', 'Solution 7: Path is going to infinity, Number of Euler steps: 0, Number of ABAM steps: 329, Number of newton iterations: 34', 'Solution 8: Path is going to infinity, Number of Euler steps: 149, Number of ABAM steps: 795, Number of new
# ...

# %% [markdown]
# Certify the solutions.

# %%
print(certify(E.F_6R_serial,sol_data_6R))
# Out:
# ('Certified solutions: 16 (total: 16), Exactly 2 real solutions, Exactly 16 distinct solutions, Maximal real and imaginary inaccuracy: 0.1992872276971462', [(array([[-0.65032982+0.01542627j],
#        [ 0.48774737-0.0115697j ],
#        [-0.58332459-0.02687226j],
#        [ 0.40452024-0.78525567j],
#        [ 1.25502221-0.12391709j],
#        [ 0.65023294+0.72769386j],
#        [ 0.14513134+0.73436186j],
#        [-0.83529132-0.67579486j],
#        [ 1.25098629-0.53642834j],
#        [ 1.10433584-0.12021998j],
#        [ 0.2042846 +0.41593182j],
#        [-0.15321345-0.31194886j]]), 'Real: False', 'Distinct'), (array([[ 0.391822  +1.11132496j],
#        [-0.2938665 -0.83349372j],
#        [ 1.68883832-0.40286714j],
#        [-1.62257524-0.08709643j],
#        [ 1.30826588-0.81863757j],
#        [ 0.54048329+1.72008109j],
#        [ 0.53642481-1.53071787j],
#        [ 1.41764645+0.56795956j],
#        [-1.16978123-0.01363433j],
#        [ 1.75883821+0.39570396j],
# ...

# %% [markdown]
# Use coefficient-parameter homotopies to solve for new parameters.

# %%
sol_data_6R_new=Homotopy_Continuation_CP(E.F_6R_serial,sol_data_6R,E.F_6R_serial_new,1,1000,(-1+1j)/(2**(1/2)))
# Out:
# <ipython-input-1-7612f9fcf5e7>:76: RuntimeWarning: divide by zero encountered in double_scalars
#   if max_eig<10 and max_eig/min_eig<10: #Checks if the difference is relatively large

# %% [markdown]
# Certify these solutions.

# %%
print(certify(E.F_6R_serial_new,sol_data_6R_new))
# Out:
# ('Certified solutions: 16 (total: 16), Exactly 2 real solutions, Exactly 16 distinct solutions, Maximal real and imaginary inaccuracy: 0.04910144436544375', [(array([[-0.65032982+0.01542627j],
#        [ 0.48774737-0.0115697j ],
#        [-0.58332459-0.02687226j],
#        [ 0.40452024-0.78525567j],
#        [ 1.25502221-0.12391709j],
#        [ 0.65023294+0.72769386j],
#        [ 0.14513134+0.73436186j],
#        [-0.83529132-0.67579486j],
#        [ 1.25098629-0.53642835j],
#        [ 1.10433584-0.12021998j],
#        [ 0.2042846 +0.41593182j],
#        [-0.15321345-0.31194886j]]), 'Real: False', 'Distinct'), (array([[ 0.391822  +1.11132496j],
#        [-0.2938665 -0.83349372j],
#        [ 1.68883832-0.40286714j],
#        [-1.62257524-0.08709643j],
#        [ 1.30826588-0.81863757j],
#        [ 0.54048329+1.72008109j],
#        [ 0.53642481-1.53071787j],
#        [ 1.41764645+0.56795956j],
#        [-1.16978123-0.01363433j],
#        [ 1.75883821+0.39570396j],
# ...
