# %% [markdown]
# File containing results of all examples used throughout the thesis.
#
# We run the file containing functions for homotopy continuation and certification, which also contains the data for our examples:

# %%
# %run Homotopy_Continuation_and_Certification.ipynb
print(Homotopy_Continuation_1(*E.Homotopy_1))
# Out:
# Solution 1: [[1.41421356-1.76566738e-09j]
#  [1.41421356-1.12011246e-09j]]
# Solution 2: Path is going to infinity
# Solution 3: [[ 1.76566738e-09+1.41421356j]
#  [-6.79491486e-09-1.41421356j]]
# Solution 4: Path is going to infinity
# Solution 5: Path is going to infinity
# Solution 6: [[-1.41421356+1.76566738e-09j]
#  [-1.41421356+1.12011246e-09j]]
# Solution 7: Path is going to infinity
# Solution 8: [[-1.76566738e-09-1.41421356j]
#  [ 6.79491486e-09+1.41421356j]]
# None
# Solution 1: [[1.41421356-6.86480595e-10j]
#  [1.41421356+3.95486226e-11j]]
# Solution 2: Path is going to infinity
# Solution 3: Path is going to infinity
# Solution 4: [[6.86480595e-10+1.41421356j]
#  [6.31816647e-09-1.41421357j]]
# Solution 5: Path is going to infinity
# Solution 6: [[-1.41421356+6.86480595e-10j]
#  [-1.41421356-3.95486226e-11j]]
# Solution 7: [[-6.86480595e-10-1.41421356j]
#  [-6.31816647e-09+1.41421357j]]
# Solution 8: Path is going to infinity
# None

# %% [markdown]
# Example 1: Plots of $h(x,t)=((1-t)\gamma-t) x^4+t(4+\gamma)-\gamma$ for 100 iterations of constant stepsize $\Delta t=\frac{1}{100}$ using Algorithm 3.3.1. Plot for $\gamma=-1$ and $\gamma=i$.

# %%
H.Homotopy_Continuation_1(*H.E.Homotopy_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fa4e155faf7f> in <module>
# ----> 1 H.Homotopy_Continuation_1(*H.E.Homotopy_1)
#
# NameError: name 'H' is not defined
